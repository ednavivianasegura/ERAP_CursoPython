# %% [markdown]
# ## Ejercicios matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Ejercicio 1:
# - Gráfica una recta de (-7, -7) a (7, 7) de color rosa.

# %%
X = np.linspace(-7, 7, 10)
Y = X

plt.plot(X, Y, color = "pink")
plt.show()

# %% [markdown]
# ### Ejercicio 2:
# - Obtén el siguiente resultado utilizando subplot y la ecuación anterior.
#
# ![matplotlib_1.png](attachment:matplotlib_1.png)

# %%
X = np.linspace(-7, 7, 10)
Y = X

colores = ["pink", "blue", "red", "magenta"]

for index, color in enumerate(colores, start = 1):

    plt.subplot(2, 2, index)
    plt.plot(X, Y, color = color)

plt.show()

# %% [markdown]
# ### Ejercicio 3:
# - Obtén la siguiente gráfica de barras.
#
# ![matplotlib_2.png](attachment:matplotlib_2.png)

# %%
valores = [10, 20, 30, 40]

colores = ["blue", "yellow", "cyan", "magenta"]

etiquetas = ["a", "b", "c", "d"]

plt.bar(etiquetas, valores, color = colores)

plt.show()

# %% [markdown]
# ### Ejercicio 4:
# - Obtener la siguiente gráfica.
#
# ![matplotlib_3.png](attachment:matplotlib_3.png)

# %%
fig, ax = plt.subplots(figsize = (12, 8))

valores1 = [10, 20, 30, 40]
valores2 = [20, 30, 40, 50]

etiquetas = ["a", "b", "c", "d"]

x = np.arange(len(etiquetas))

ancho = 0.5

plt.bar(x - ancho/2, valores1, width = ancho, color = "cyan")
plt.bar(x + ancho/2, valores2, width = ancho , color = "magenta")

plt.show()

# %% [markdown]
# ### Ejercicio 5:
# - Obtener el histograma del último atributo del dataset de la iris.
#
# ![matplotlib_4.png](attachment:matplotlib_4.png)

# %%
iris = pd.read_csv("Data/iris.csv")

iris.head(3)
# Out:
#    Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo        Clase
# 0           5.1           3.5           1.4           0.2  Iris-setosa
# 1           4.9           3.0           1.4           0.2  Iris-setosa
# 2           4.7           3.2           1.3           0.2  Iris-setosa

# %%
plt.hist(iris["Ancho Petalo"], bins = 30, color = "magenta")
plt.show()

# %% [markdown]
# ### Ejercicio 6:
# - Muestra los histogramas de los últimos dos atributos de la iris plant.
#
# ![matplotlib_5.png](attachment:matplotlib_5.png)

# %%
plt.hist(iris["Largo Petalo"], bins = 30, color = "magenta", alpha = 0.5)
plt.hist(iris["Ancho Petalo"], bins = 30, color = "cyan", alpha = 0.5)

plt.show()

# %% [markdown]
# ### Ejercicio 7:
# - Guarda el dataset de titanic en una variable.

# %%
titanic = pd.read_csv("Data/titanic.csv")

titanic.head(3)
# Out:
#    PassengerId                                               Name     Sex  \
# 0            1                            Braund, Mr. Owen Harris    male
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2            3                             Heikkinen, Miss. Laina  female
#
#     Age  Survived  Pclass            Ticket     Fare
# 0  22.0         0       3         A/5 21171   7.2500
# 1  38.0         1       1          PC 17599  71.2833
# 2  26.0         1       3  STON/O2. 3101282   7.9250

# %% [markdown]
# ### Ejercicio 8:
# - Muestra en una grafica de barras el número de hombres y mujeres que sobrevivieron.
#
# ![matplotlib_6.png](attachment:matplotlib_6.png)

# %%
etiquetas = titanic[titanic["Survived"] == 1].value_counts("Sex", sort = False).index

valores = titanic[titanic["Survived"] == 1].value_counts("Sex", sort = False).values


plt.bar(etiquetas, valores, color = "green")
plt.show()

# %% [markdown]
# ### Ejercicio 9:
# - Muestra en una grafica de barras el número de hombres y mujeres que sobrevivieron.
#
# ![matplotlib_7.png](attachment:matplotlib_7.png)

# %%
etiquetas = sorted(titanic["Sex"].unique())
etiquetas
# Out:
# ['female', 'male']

# %%
fig, ax = plt.subplots()

etiquetas = sorted(titanic["Sex"].unique())

valores1 = titanic[titanic["Survived"] == 1].value_counts("Sex", sort = False).values
valores2 = titanic[titanic["Survived"] == 0].value_counts("Sex", sort = False).values


x = np.arange(len(etiquetas))  
width = 0.4

plt.bar(x - width/2, valores1, width, color = "blue")
plt.bar(x + width/2, valores2, width, color = "red")

ax.set_xticks(x)
ax.set_xticklabels(etiquetas)

plt.show()

# %% [markdown]
# ### Ejercicio 10:
# - Muestra en una grafica de barras agrupada la cantidad de hombres y mujeres de cada clase (**`Pclass`**).
#
# ![matplotlib_8.png](attachment:matplotlib_8.png)

# %%
fig, ax = plt.subplots(figsize = (10, 6))

etiquetas = sorted(titanic["Sex"].unique())

valores1 = titanic[titanic["Pclass"] == 1]["Sex"].value_counts(sort = False).values
valores2 = titanic[titanic["Pclass"] == 2]["Sex"].value_counts(sort = False).values
valores3 = titanic[titanic["Pclass"] == 3]["Sex"].value_counts(sort = False).values

x = np.arange(len(etiquetas))  

width = 0.4

plt.bar(x + width/1, valores3, 0.2, color = "green", label = "Clase 3")
plt.bar(x - width/3, valores1, 0.2, color = "blue", label = "Clase 1")
plt.bar(x + width/3, valores2, 0.2, color = "red", label = "Clase 2")

plt.legend(loc = "best")

ax.set_xticks(x)
ax.set_xticklabels(etiquetas)

plt.show()

# %% [markdown]
# ### Ejercicio 11:
# - Muestra en una gráfica el número de sobrevivientes por clase (**`Pclass`**).
#
# ![matplotlib_9.png](attachment:matplotlib_9.png)

# %%
etiquetas = [f"Clase {i}" for i in titanic[titanic["Survived"] == 1].value_counts("Pclass", sort = False).index]

valores = titanic[titanic["Survived"] == 1].value_counts("Pclass", sort = False).values

colores = ["blue", "green", "red"]

plt.bar(etiquetas, valores, color = colores)

plt.show()

# %% [markdown]
# ### Ejercicio 12:
# - Muestra en una gráfica de sectores el número de los que no sobrevivieron por clase (**`Pclass`**).
#
# ![matplotlib_10.png](attachment:matplotlib_10.png)

# %%
titanic[titanic["Survived"] == 0]["Pclass"].value_counts(sort = False, normalize = True)
# Out:
# 3    0.677596
# 1    0.145719
# 2    0.176685
# Name: Pclass, dtype: float64

# %%
fig, ax = plt.subplots(figsize = (8, 8))

labels = sorted([f"Clase {x}" for x in titanic["Pclass"].unique()])

ax.pie(x         = titanic[titanic["Survived"] == 0]["Pclass"].value_counts(sort = False).values,
       labels    = labels,
       colors    = ["yellow", "beige", "pink"],
       shadow    = True,
       explode   = (0.04, 0.04, 0.04),
       autopct   = "%1.1f%%",
       textprops = {"fontsize" : 25})  
plt.show()

# %% [markdown]
# ### Ejercicio 13:
# - Muestra en 2 graficas de sectores con **`plt.subplots()`** la siguiente información:
#     1. En la primera gráfica mostrar el número de pasajeros que murieron de cada clase.
#     2. En la segunda gráfica mostrar el número de pasajeros que sobrevivieron de cada clase.
#
# ![matplotlib_11.png](attachment:matplotlib_11.png)

# %%
titanic[titanic["Survived"] == 0]["Pclass"].value_counts(sort = False, normalize = True)
# Out:
# 3    0.677596
# 1    0.145719
# 2    0.176685
# Name: Pclass, dtype: float64

# %%
titanic[titanic["Survived"] == 1]["Pclass"].value_counts(sort = False, normalize = True)
# Out:
# 1    0.397661
# 3    0.347953
# 2    0.254386
# Name: Pclass, dtype: float64

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (10, 10))

labels = sorted([f"Clase {x}" for x in titanic["Pclass"].unique()])

ax[0].pie(x       = titanic[titanic["Survived"] == 0]["Pclass"].value_counts(sort = False).values,
          labels  = labels,
          colors  = ["yellow", "beige", "pink"],
          shadow  = True,
          explode = (0.04, 0.04, 0.04),
          autopct = "%1.2f%%")  


ax[1].pie(x       = titanic[titanic["Survived"] == 1]["Pclass"].value_counts(sort = False).values,
          labels  = labels,
          colors  = ["yellow", "beige", "pink"],
          shadow  = True,
          explode = (0.04, 0.04, 0.04),
          autopct = "%1.2f%%")  

plt.show()

# %% [markdown]
# ### Ejercicio 14:
# - Muestra en una gráfica lineal las edades de los pasajeros que sobrevivieron y en otra la de los pasajeros que no sobrevivieron.
#
# ![matplotlib_12.png](attachment:matplotlib_12.png)

# %%
plt.figure(figsize = (18, 2))

plt.plot(titanic[titanic["Survived"] == 1]["Age"], color = "blue")

plt.plot(titanic[titanic["Survived"] == 0]["Age"], color = "red")

plt.show()

# %% [markdown]
# ### Ejercicio 15:
# - Muestra en una grafica de caja la edad de los que sobrevivieron y de los que no sobrevivieron.
#
# **Nota**: Para poder graficarlo hay que reemplazar los NaN por el promedio de edad.
#
# ![matplotlib_13.png](attachment:matplotlib_13.png)

# %%
titanic["Age"].replace(np.nan, titanic["Age"].mean(), inplace = True)

# %%
etiquetas = ["Survived" if i == 1 else "Not Survived" for i in titanic["Survived"].unique()]


data1 = titanic[titanic["Survived"] == 0]["Age"]
data2 = titanic[titanic["Survived"] == 1]["Age"]

data = [data1, data2]

plt.boxplot(x = data, labels = etiquetas)
plt.show()

# %% [markdown]
# ### Ejercicio 16:
# - Mostrar en una gráfica de caja por clase la edad de los pasajeros.
#
# ![matplotlib_14.png](attachment:matplotlib_14.png)

# %%
etiquetas = [f"Clase {i}" for i in titanic.value_counts("Pclass", sort = False).index]

datos = [titanic[titanic["Pclass"] == 1]["Age"],
         titanic[titanic["Pclass"] == 2]["Age"],
         titanic[titanic["Pclass"] == 3]["Age"]]

plt.boxplot(x = datos, labels = etiquetas)

plt.show()

# %% [markdown]
# ### Ejercicio 17:
# - Muestra en una gráfica de dispersión (scatter) la edad de los pasajeros vs el costo de su ticket.
#
# ![matplotlib_15.png](attachment:matplotlib_15.png)

# %%
plt.scatter(x = titanic["Age"], y = titanic["Fare"])

plt.title("scatter")

plt.show()

# %% [markdown]
# ### Ejercicio 18:
# - Muestra en una gráfica de dispersión la clase vs el el precio del ticket.
#
# ![matplotlib_16.png](attachment:matplotlib_16.png)

# %%
plt.scatter(x = titanic["Pclass"], y = titanic["Fare"])

plt.title("scatter")

plt.show()

# %% [markdown]
# ### Ejercicio 19:
# - Muestra en un histograma la edad de los pasajeros que sobrevivieron y la edad de los que no.
#
# ![matplotlib_17.png](attachment:matplotlib_17.png)

# %%
plt.hist(x = titanic[titanic["Survived"] == 1]["Age"], bins = 30, alpha = 0.45, color = "Blue")
plt.hist(x = titanic[titanic["Survived"] == 0]["Age"], bins = 30, alpha = 0.3, color = "Green")

plt.show()

# %% [markdown]
# ### Ejercicio 20:
# - Muestra en un histograma el costo de boleto por clase.
#
# ![matplotlib_18.png](attachment:matplotlib_18.png)

# %%
plt.figure(figsize = (12, 6))

plt.hist(x = titanic[titanic["Pclass"] == 1]["Fare"], bins = 10, alpha = 0.45, color = "Blue")
plt.hist(x = titanic[titanic["Pclass"] == 2]["Fare"], bins = 10, alpha = 0.45, color = "Red")
plt.hist(x = titanic[titanic["Pclass"] == 3]["Fare"], bins = 10, alpha = 0.3, color = "Green")

plt.show()
